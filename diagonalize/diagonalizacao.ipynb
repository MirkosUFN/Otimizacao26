# %%
import pandas as pd

#inicialmente o sistema será de duas equações com
#duas variáveis
matriz = [[1,-2,4],[3,1,2]]
print(matriz[0][0])#valor da diagonal
print(matriz[1][1])#valor da diagonal

print(matriz[1][0])#valor abaixo da diagonal
print(matriz[0][1])#valor acima da diagonal

condicao = False
while(condicao==False):

  d0=matriz[0][0]
  d1=matriz[1][1]
  val0=matriz[1][0]
  val1=matriz[0][1]
  if(d0==1.0 and d1==1.0 and val0==0.0 and val1==0.0):
    condicao = True
    continue
  if(d0!=1):
    divisor=d0
    print(divisor)
    matriz[0][0]=matriz[0][0]/divisor
    matriz[0][1]=matriz[0][1]/divisor
    matriz[0][2]=matriz[0][2]/divisor
    continue
  if(d1!=1):
    divisor=d1
    print(divisor)
    matriz[1][0]=matriz[1][0]/divisor
    matriz[1][1]=matriz[1][1]/divisor
    matriz[1][2]=matriz[1][2]/divisor
    continue
  if val0 != 0: #d0 deve ser = 1
    val = -val0 #inverte o sinal
    matriz[1][0]=(val*matriz[0][0])+matriz[1][0]
    matriz[1][1]=(val*matriz[0][1])+matriz[1][1]
    matriz[1][2]=(val*matriz[0][2])+matriz[1][2]
    continue
  if val1 != 0: #d1 deve ser = 1
    val = -val1 #inverte o sinal
    matriz[0][0]=(val*matriz[1][0])+matriz[0][0]
    matriz[0][1]=(val*matriz[1][1])+matriz[0][1]
    matriz[0][2]=(val*matriz[1][2])+matriz[0][2]
    continue

  #condicao = True
print(matriz)
# Out:
# 1
# 1
# 3
# -2
# 7
# [[1.0, 0.0, 1.1428571428571428], [0.0, 1.0, -1.4285714285714286]]
